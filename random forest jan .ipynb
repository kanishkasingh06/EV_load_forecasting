# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

# Load the data for cities A, B, C, and D
city_A_data = pd.read_csv('Amsterdam.csv')
city_B_data = pd.read_csv('Beijing.csv')
city_C_data = pd.read_csv('NewYork.csv')
city_D_data = pd.read_csv('Paris.csv')
city_E_data = pd.read_csv('Beijing.csv')
city_F_data = pd.read_csv('London.csv')

combined_data = pd.concat([city_A_data, city_B_data, city_C_data, city_E_data, city_F_data], ignore_index=True)


# Define the features (independent variables) and the targets (dependent variables) for the combined dataset
X_combined = combined_data[['CPI', 'GNI per capita ', 'Average years of schooling',
       'Life expectancy (years)', 'CO2 level (t/capita)', 'PM2.5 pollution',
       'Per capita energy consumption (kWh)']]
y_combined = combined_data[['EVs sold as a percentage of all cars',
       'EVs sold as a percentage of entry-level cars',
       'EVs sold as a percentage of compact cars',
       'EVs sold as a percentage of mid-size cars',
       'EVs sold as a percentage of premium cars']]

# Split the combined data into training and testing sets



# Load the features for city D
X_D = city_D_data[['CPI', 'GNI per capita ', 'Average years of schooling',
       'Life expectancy (years)', 'CO2 level (t/capita)', 'PM2.5 pollution',
       'Per capita energy consumption (kWh)']]
Y_D = city_D_data[['EVs sold as a percentage of entry-level cars',
       'EVs sold as a percentage of compact cars',
       'EVs sold as a percentage of mid-size cars',
       'EVs sold as a percentage of premium cars']] 
# Predict EV sales percentages for city D
X_combined_train, X_combined_test, y_combined_train, y_combined_test = train_test_split(X_combined, y_combined, test_size=0.2, random_state=42)
# Create a Random Forest Regressor model for non-linear regression
model = RandomForestRegressor(n_estimators=100, random_state=42)

# Train the model on the combined data
model.fit(X_combined_train, y_combined_train)

predicted_sales_percentages_D = model.predict(X_D)
# Evaluate the model's performance on the test set
mse_combined = mean_squared_error(y_combined_test, model.predict(X_combined_test))
r2_combined = r2_score(y_combined_test, model.predict(X_combined_test))

# Output the results and error analysis for predicting city D
print("Predicted EV Sales Percentages for City D:", predicted_sales_percentages_D)
predicted_sales_percentages_D = 
print("Error Analysis for the Combined Model:")
print("Mean Squared Error:", mse_combined)
print("R-squared (R2) Score:", r2_combined)
# Out:
#   Cell In[25], line 54
#     predicted_sales_percentages_D =
#                                     ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt
# Create a scatter plot of expected vs. predicted values for city D
df = pd.DataFrame(predicted_sales_percentages_D, columns=['EVs sold as a percentage of all cars',
       'EVs sold as a percentage of entry-level cars',
       'EVs sold as a percentage of compact cars',
       'EVs sold as a percentage of mid-size cars',
       'EVs sold as a percentage of premium cars'])
plt.scatter( df['EVs sold as a percentage of all cars'], Y_D['EVs sold as a percentage of all cars'] , label='Expected vs. Predicted for City D')
plt.plot([0, 0.22], [0, 0.22], color='red', linestyle='--', label='y=x')
plt.xlabel('Expected EV Sales Percentage')
plt.ylabel('Predicted EV Sales Percentage')
plt.title('Expected vs. Predicted EV Sales Percentage for City D')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 import matplotlib.pyplot as plt
#       2 # Create a scatter plot of expected vs. predicted values for city D
# ----> 3 df = pd.DataFrame(predicted_sales_percentages_D, columns=['EVs sold as a percentage of all cars',
#       4        'EVs sold as a percentage of entry-level cars',
#       5        'EVs sold as a percentage of compact cars',
#       6        'EVs sold as a percentage of mid-size cars',
#       7        'EVs sold as a percentage of premium cars'])
#       8 plt.scatter( df['EVs sold as a percentage of all cars'], Y_D['EVs sold as a percentage of all cars'] , label='Expected vs. Predicted for City D')
#       9 plt.plot([0, 0.22], [0, 0.22], color='red', linestyle='--', label='y=x')
#
# NameError: name 'pd' is not defined

# %%
type(predicted_sales_percentages_D)
# Out:
# numpy.ndarray

# %%
city_G_data = pd.read_csv('Delhi.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 city_G_data = pd.read_csv('Delhi.csv')
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Assuming X contains your features and Y contains your labels

# Load the data for cities A, B, C, and D
city_A_data = pd.read_csv('Amsterdam.csv')
city_B_data = pd.read_csv('Beijing.csv')
city_C_data = pd.read_csv('NewYork.csv')
city_D_data = pd.read_csv('Paris.csv')
city_E_data = pd.read_csv('Beijing.csv')
city_F_data = pd.read_csv('London.csv')

combined_data = pd.concat([city_A_data, city_B_data, city_C_data, city_D_data, city_E_data, city_F_data], ignore_index=True)


# Define the features (independent variables) and the targets (dependent variables) for the combined dataset
X_combined = combined_data[['CPI', 'GNI per capita ', 'Average years of schooling',
       'Life expectancy (years)', 'CO2 level (t/capita)', 'PM2.5 pollution',
       'Per capita energy consumption (kWh)']]
y_combined = combined_data[['EVs sold as a percentage of entry-level cars',
       'EVs sold as a percentage of compact cars',
       'EVs sold as a percentage of mid-size cars',
       'EVs sold as a percentage of premium cars']]

# Split the combined data into training and testing sets

# Split the data
X_train, X_test, Y_train, Y_test = train_test_split(X_combined, y_combined, test_size=0.2, random_state=42)

# Choose a regression model (Linear Regression in this example)
regressor = LinearRegression()

# Train the model
regressor.fit(X_train, Y_train)

# Predictions on the test set
predictions = regressor.predict(X_test)

# Evaluate the model
mse = mean_squared_error(Y_test, predictions)
print(f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 0.00017398250019868956

# %%
city_G_data = pd.read_csv("Delhi.csv")
X_G = city_G_data[['CPI', 'GNI per capita ', 'Average years of schooling',
       'Life expectancy (years)', 'CO2 level (t/capita)', 'PM2.5 pollution',
       'Per capita energy consumption (kWh)']]
predicted_sales_percentages_G = regressor.predict(X_G)
print(predicted_sales_percentages_G)
# Out:
# [[-0.5709037  -0.30726525 -0.10413333 -0.08377739]
#  [-0.4338004  -0.2326997  -0.07630567 -0.06383497]
#  [-0.28726401 -0.15296279 -0.04647295 -0.04241997]
#  [-0.13255635 -0.06874503 -0.01490056 -0.01972635]
#  [ 0.0286401   0.01903295  0.01805764  0.0039873 ]
#  [ 0.19674596  0.11060131  0.0524901   0.02878561]
#  [ 0.37134062  0.20572988  0.08830837  0.05460394]
#  [ 0.55242407  0.30441866  0.12551244  0.08144228]
#  [ 0.7395757   0.4064375   0.16401386  0.109236  ]
#  [ 0.93321613  0.51201655  0.20390107  0.13804973]
#  [ 1.13029331  0.61948001  0.24451954  0.16740077]
#  [ 1.32694089  0.72670791  0.2850466   0.19668465]]

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming Y_test and predictions are the true and predicted values for the 4 labels in the testing set
y_test= np.array(Y_test)


# Plotting for the first dimension
for i in range(4):
    
    plt.figure(figsize=(10, 6))
    plt.scatter(y_test[:, i], abs(predictions[:, i]), color='blue', label='Dimension' )
    plt.plot([0,0.4], [0,0.4], linestyle='--', color='gray', label='Identity Line')
    plt.title('Expected vs Predicted - Dimension 1')
    plt.xlabel('Expected')
    plt.ylabel('Predicted')
    plt.legend()
    plt.show()

# Similar plots for the other dimensions (2, 3, and 4)
# Repeat the code above, changing the indices accordingly (0 -> 1, 1 -> 2, and so on)
# Adjust figsize, titles, and labels as needed

# %%
valid_indices = np.where((Y_test >= 0).all(axis=1) & (predictions >= 0).all(axis=1))

# Plotting for the first dimension
plt.figure(figsize=(10, 6))
plt.scatter(Y_test[valid_indices, 0], predictions[valid_indices, 0], color='blue', label='Dimension 1')
plt.plot([min(Y_test[valid_indices, 0]), max(Y_test[valid_indices, 0])], [min(Y_test[valid_indices, 0]), max(Y_test[valid_indices, 0])], linestyle='--', color='gray', label='Identity Line')
plt.title('Expected vs Predicted - Dimension 1')
plt.xlabel('Expected')
plt.ylabel('Predicted')
plt.legend()
plt.show()

# %%
print(y_test)
# Out:
# (array([ 0,  1,  2,  4,  5,  6,  8,  9, 10, 11, 12, 13, 14, 15],
#       dtype=int64),)

# %%
print(predictions)
# Out:
# [[ 5.49536306e-02  2.74093491e-02  5.30424618e-03  2.59775424e-03]
#  [ 1.74370284e-01  8.71928951e-02  1.74697612e-02  8.80645896e-03]
#  [ 1.83477892e-01  9.16444589e-02  1.81692659e-02  8.93693656e-03]
#  [-3.07292102e-02 -1.54140575e-02 -3.27243366e-03 -1.62836731e-03]
#  [ 1.10289590e-01  5.51435273e-02  1.10948038e-02  5.54020341e-03]
#  [ 1.53131010e-01  7.65552306e-02  1.53831437e-02  7.65326419e-03]
#  [ 3.31109747e-02  1.96429769e-02  1.12147412e-02  6.25816892e-03]
#  [-8.34777071e-04 -4.04717329e-04 -2.11331686e-05  2.10373935e-06]
#  [ 2.17393141e-01  1.08672785e-01  2.18156536e-02  1.08228554e-02]
#  [ 2.44253131e-02  1.22519337e-02  2.46057146e-03  1.41074625e-03]
#  [ 3.48243263e-02  2.09706781e-02  1.25309741e-02  7.29487601e-03]
#  [ 6.11724545e-02  3.78421300e-02  2.38319234e-02  1.65957526e-02]
#  [ 8.63246441e-02  4.31568925e-02  8.61836978e-03  4.30423771e-03]
#  [ 2.45846595e-01  1.23836438e-01  2.67370429e-02  1.43670159e-02]
#  [ 1.08114499e-01  5.40472949e-02  1.07782455e-02  5.37977121e-03]
#  [ 1.31528864e-01  6.57811918e-02  1.31814213e-02  6.69339819e-03]]

# %%
print(y)
print(p)
# Out:
# [[0.05   0.025  0.005  0.0025]
#  [0.16   0.08   0.016  0.008 ]
#  [0.2    0.1    0.02   0.01  ]
#  [0.01   0.005  0.001  0.0005]
#  [0.08   0.04   0.008  0.004 ]
#  [0.12   0.06   0.012  0.006 ]
#  [0.031  0.017  0.009  0.006 ]
#  [0.02   0.01   0.002  0.001 ]
#  [0.24   0.12   0.024  0.012 ]
#  [0.03   0.015  0.003  0.002 ]
#  [0.039  0.023  0.014  0.008 ]
#  [0.065  0.04   0.025  0.018 ]
#  [0.06   0.03   0.006  0.003 ]
#  [0.28   0.14   0.028  0.014 ]
#  [0.08   0.04   0.008  0.004 ]
#  [0.1    0.05   0.01   0.005 ]]
# [[ 5.49536306e-02  2.74093491e-02  5.30424618e-03  2.59775424e-03]
#  [ 1.74370284e-01  8.71928951e-02  1.74697612e-02  8.80645896e-03]
#  [ 1.83477892e-01  9.16444589e-02  1.81692659e-02  8.93693656e-03]
#  [-3.07292102e-02 -1.54140575e-02 -3.27243366e-03 -1.62836731e-03]
#  [ 1.10289590e-01  5.51435273e-02  1.10948038e-02  5.54020341e-03]
#  [ 1.53131010e-01  7.65552306e-02  1.53831437e-02  7.65326419e-03]
#  [ 3.31109747e-02  1.96429769e-02  1.12147412e-02  6.25816892e-03]
#  [-8.34777071e-04 -4.04717329e-04 -2.11331686e-05  2.10373935e-06]
#  [ 2.17393141e-01  1.08672785e-01  2.18156536e-02  1.08228554e-02]
#  [ 2.44253131e-02  1.22519337e-02  2.46057146e-03  1.41074625e-03]
#  [ 3.48243263e-02  2.09706781e-02  1.25309741e-02  7.29487601e-03]
#  [ 6.11724545e-02  3.78421300e-02  2.38319234e-02  1.65957526e-02]
#  [ 8.63246441e-02  4.31568925e-02  8.61836978e-03  4.30423771e-03]
#  [ 2.45846595e-01  1.23836438e-01  2.67370429e-02  1.43670159e-02]
#  [ 1.08114499e-01  5.40472949e-02  1.07782455e-02  5.37977121e-03]
#  [ 1.31528864e-01  6.57811918e-02  1.31814213e-02  6.69339819e-03]]

# %%
plt.figure(figsize=(6, 6))
plt.scatter(y[:, 3], abs(p[:, 3]), color='blue' )
plt.plot([0,0.03], [0,0.03], linestyle='--', color='gray', label='Identity Line')
plt.title('Expected vs Predicted - percentages of luxury vehicles that are EVs')
plt.xlabel('Expected')
plt.ylabel('Predicted')
plt.legend()
plt.show()

# %%
print(predicted_sales_percentages_G[4:])
# Out:
# [[0.0286401  0.01903295 0.01805764 0.0039873 ]
#  [0.19674596 0.11060131 0.0524901  0.02878561]
#  [0.37134062 0.20572988 0.08830837 0.05460394]
#  [0.55242407 0.30441866 0.12551244 0.08144228]
#  [0.7395757  0.4064375  0.16401386 0.109236  ]
#  [0.93321613 0.51201655 0.20390107 0.13804973]
#  [1.13029331 0.61948001 0.24451954 0.16740077]
#  [1.32694089 0.72670791 0.2850466  0.19668465]]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Assuming X contains your features and Y contains your labels

# Load the data for cities A, B, C, and D
city_A_data = pd.read_csv('Amsterdam.csv')
city_B_data = pd.read_csv('Beijing.csv')
city_C_data = pd.read_csv('NewYork.csv')
city_D_data = pd.read_csv('Paris.csv')
city_E_data = pd.read_csv('Beijing.csv')
city_F_data = pd.read_csv('London.csv')

combined_data = pd.concat([city_A_data, city_B_data, city_C_data, city_D_data, city_E_data, city_F_data], ignore_index=True)


# Define the features (independent variables) and the targets (dependent variables) for the combined dataset
X_combined = combined_data[['CPI', 'GNI per capita ', 'Average years of schooling',
       'Life expectancy (years)', 'CO2 level (t/capita)', 'PM2.5 pollution',
       'Per capita energy consumption (kWh)']]
y_combined = combined_data[['EVs sold as a percentage of all cars','EVs sold as a percentage of entry-level cars',
       'EVs sold as a percentage of compact cars',
       'EVs sold as a percentage of mid-size cars',
       'EVs sold as a percentage of premium cars']]

# Split the combined data into training and testing sets

# Split the data
X_train, X_test, Y_train, Y_test = train_test_split(X_combined, y_combined, test_size=0.2, random_state=42)

# Choose a regression model (Linear Regression in this example)
regressor = LinearRegression()

# Train the model
regressor.fit(X_train, Y_train)

# Predictions on the test set
predictions = regressor.predict(X_test)

# Evaluate the model
mse = mean_squared_error(Y_test, predictions)
print(f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 0.0001682498104846073

# %%
city_G_data = pd.read_csv("Delhi.csv")
X_G = city_G_data[['CPI', 'GNI per capita ', 'Average years of schooling',
       'Life expectancy (years)', 'CO2 level (t/capita)', 'PM2.5 pollution',
       'Per capita energy consumption (kWh)']]
predicted_sales_percentages_G = regressor.predict(X_G)
print(predicted_sales_percentages_G)
# Out:
# [[-0.14500861 -0.5709037  -0.30726525 -0.10413333 -0.08377739]
#  [-0.09029041 -0.4338004  -0.2326997  -0.07630567 -0.06383497]
#  [-0.0320295  -0.28726401 -0.15296279 -0.04647295 -0.04241997]
#  [ 0.02929437 -0.13255635 -0.06874503 -0.01490056 -0.01972635]
#  [ 0.09304151  0.0286401   0.01903295  0.01805764  0.0039873 ]
#  [ 0.15937183  0.19674596  0.11060131  0.0524901   0.02878561]
#  [ 0.22812542  0.37134062  0.20572988  0.08830837  0.05460394]
#  [ 0.29930227  0.55242407  0.30441866  0.12551244  0.08144228]
#  [ 0.37274246  0.7395757   0.4064375   0.16401386  0.109236  ]
#  [ 0.44860591  0.93321613  0.51201655  0.20390107  0.13804973]
#  [ 0.52575852  1.13029331  0.61948001  0.24451954  0.16740077]
#  [ 0.60274998  1.32694089  0.72670791  0.2850466   0.19668465]]

# %%
[0.03,0.09,0.16,0.23,0.30,0.37,0.45,0.53,0.6]
