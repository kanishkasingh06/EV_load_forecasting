# [33.124334555779015, 37.05367168201212, 40.49445865302643, 43.50025290844714, 45.16625024024601, 46.55833485484754, 48.564738530916664, 51.07925523150437, 53.994835276625714, 57.2448145119322, 56.497175141242934, 57.69488796457802, 58.628600560795306, 59.705129767271835, 67.82259966973342, 75.93057775747889, 78.47471677258912, 77.04242683644536, 81.30923403594178, 85.23012132758447, 88.80908473260216, 87.38548273431995, 91.4134982717846, 95.5357929030554, 99.727241732015, 101.901893642477, 105.03614361595909, 107.86360473208073, 111.90119760479044, 114.12216506050287, 116.78473732201726, 110.5479778223749, 109.27338153246839, 108.39934575542797]

# %%
print(len(a1))
print(len(b1))
print(len(b1_prev))
# Out:
# 34
# 50
# 54

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import tensorflow as tf
tf.config.run_functions_eagerly(True)

def model(arr):
    # Assuming you have a sequence of 40 points in the 'data' array
    data = np.array(arr)  # Replace this with your actual data

    # Create a function to generate training samples
    def create_sequences(data, sequence_length):
        sequences = []
        for i in range(len(data) - sequence_length):
            seq = data[i:i + sequence_length]
            label = data[i + sequence_length]
            sequences.append((seq, label))
        return np.array(sequences)

    # Define the sequence length
    sequence_length = 1

    # Create training sequences
    training_data = create_sequences(data, sequence_length)

    # Split the data into input (X) and output (y)
    X_train = np.array([seq for seq, label in training_data])
    y_train = np.array([label for seq, label in training_data])

    # Reshape the input data for LSTM (samples, time steps, features)
    X_train = np.reshape(X_train, (X_train.shape[0], sequence_length, 1))

    # Build the LSTM model
    model = Sequential()
    model.add(LSTM(units=50, activation='relu', input_shape=(sequence_length, 1)))
    model.add(Dense(units=1))

    model.compile(optimizer='adam', loss='mean_squared_error', run_eagerly=True)
    # Train the model
    model.fit(X_train, y_train, epochs=10, batch_size=1)

    # Now, you can use the trained model to predict the next points
    # For example, let's predict the next point after the last 40 points in the 'data' array
    last_sequence = data[-sequence_length:]
    last_sequence = np.reshape(last_sequence, (1, sequence_length, 1))
    predicted_point = model.predict(last_sequence)

    return predicted_point[0, 0]

# %%
for i in range(12):
    predicted_point = model(b1)
    b1=b1.append(predicted_point)

print(b1)
# Out:
# Epoch 1/10
#  1/39 [..............................] - ETA: 1s - loss: 15450736.0000
# C:\Users\rituv\AppData\Local\Temp\ipykernel_16692\71279818.py:19: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.array(sequences)
# 39/39 [==============================] - 1s 15ms/step - loss: 5911834.5000
# Epoch 2/10
# 39/39 [==============================] - 1s 15ms/step - loss: 5500613.0000
# Epoch 3/10
# 39/39 [==============================] - 1s 14ms/step - loss: 5137239.0000
# Epoch 4/10
# 39/39 [==============================] - 1s 14ms/step - loss: 4393380.5000
# Epoch 5/10
# 39/39 [==============================] - 1s 14ms/step - loss: 3436581.7500
# Epoch 6/10
# 39/39 [==============================] - 1s 15ms/step - loss: 3000230.7500
# Epoch 7/10
# ...

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import LSTM, Dense

# Generate some example data
# Replace this with your actual data
data = np.array(b1)

# Define the number of input and output points
input_length = 4
output_length =2

# Prepare the data in the required format for training
X, y = [], []
for i in range(len(data) - input_length - output_length + 1):
    X.append(data[i:i+input_length])
    y.append(data[i+input_length:i+input_length+output_length])

X = np.array(X)
y = np.array(y)

# Reshape the input data for LSTM (samples, time steps, features)
X = np.reshape(X, (X.shape[0], X.shape[1], 1))

# Define the LSTM model
model = Sequential()
model.add(LSTM(units=50, activation='relu', input_shape=(input_length, 1)))
model.add(Dense(units=output_length))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(X, y, epochs=50, batch_size=32)

# Now you can use the trained model to predict the next 12 points
# Assuming 'input_data' is the last 40 points in your sequence
input_data = data[-input_length:]
input_data = np.reshape(input_data, (1, input_length, 1))
predicted_output = model.predict(input_data)

print("Predicted Output:", predicted_output[0])
# Out:
# Epoch 1/50
# 2/2 [==============================] - 0s 23ms/step - loss: 16683173.0000
# Epoch 2/50
# 2/2 [==============================] - 0s 25ms/step - loss: 16662575.0000
# Epoch 3/50
# 2/2 [==============================] - 0s 34ms/step - loss: 16389189.0000
# Epoch 4/50
# 2/2 [==============================] - 0s 26ms/step - loss: 16016287.0000
# Epoch 5/50
# 2/2 [==============================] - 0s 24ms/step - loss: 15458969.0000
# Epoch 6/50
# 2/2 [==============================] - 0s 40ms/step - loss: 15081553.0000
# Epoch 7/50
# 2/2 [==============================] - 0s 27ms/step - loss: 14870113.0000
# Epoch 8/50
# 2/2 [==============================] - 0s 25ms/step - loss: 14615852.0000
# Epoch 9/50
# 2/2 [==============================] - 0s 44ms/step - loss: 14395508.0000
# Epoch 10/50
# 2/2 [==============================] - 0s 25ms/step - loss: 14119608.0000
# Epoch 11/50
# 2/2 [==============================] - 0s 27ms/step - loss: 13880215.0000
# Epoch 12/50
# ...

# %%
print(training_data)
# Out:
# [[array([299.65, 301.23]) 326.61]
#  [array([301.23, 326.61]) 274.84]
#  [array([326.61, 274.84]) 293.26]
#  [array([274.84, 293.26]) 284.19]
#  [array([293.26, 284.19]) 333.01]
#  [array([284.19, 333.01]) 366.6]
#  [array([333.01, 366.6 ]) 399.79]
#  [array([366.6 , 399.79]) 423.19]
#  [array([399.79, 423.19]) 428.77]
#  [array([423.19, 428.77]) 466.87]
#  [array([428.77, 466.87]) 476.61]
#  [array([466.87, 476.61]) 493.95]
#  [array([476.61, 493.95]) 523.97]
#  [array([493.95, 523.97]) 618.36]
#  [array([523.97, 618.36]) 721.59]
#  [array([618.36, 721.59]) 834.22]
#  [array([721.59, 834.22]) 949.12]
#  [array([834.22, 949.12]) 1238.7]
#  [array([ 949.12, 1238.7 ]) 1224.1]
#  [array([1238.7, 1224.1]) 1365.37]
#  [array([1224.1 , 1365.37]) 1708.46]
#  [array([1365.37, 1708.46]) 1823.05]
#  [array([1708.46, 1823.05]) 1827.64]
#  [array([1823.05, 1827.64]) 1856.72]
#  [array([1827.64, 1856.72]) 2039.13]
#  [array([1856.72, 2039.13]) 2103.59]
#  [array([2039.13, 2103.59]) 2294.8]
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Example data - replace this with your own dataset
x_sequence = np.arange(1, 35)  # Assuming a sequence of 34 points
y_sequence = np.array(b1)  # Replace with actual y values

# Choose the degree of the polynomial
degree = 3

# Perform polynomial regression
coefficients = np.polyfit(x_sequence, y_sequence, degree)

# Form the polynomial equation
equation = np.poly1d(coefficients)
print("Polynomial Equation:", equation)

# Generate 20 new points for prediction
x_pred = np.arange(35, 55)  # Assuming you want to predict the next 20 points

# Make predictions using the polynomial equation
y_pred = equation(x_pred)

# Store predicted points in an array
predicted_points = np.column_stack((x_pred, y_pred))
print("Predicted Points:")
print(predicted_points)

# Plot expected vs. predicted values
plt.scatter(x_sequence, y_sequence, label='Expected Values', color='blue')
plt.scatter(x_pred, y_pred, label='Predicted Values', color='red')
plt.plot(x_sequence, equation(x_sequence), label='Fitted Curve', color='green')

# Customize the plot
plt.title('Polynomial Regression Prediction')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 12
#       9 degree = 3
#      11 # Perform polynomial regression
# ---> 12 coefficients = np.polyfit(x_sequence, y_sequence, degree)
#      14 # Form the polynomial equation
#      15 equation = np.poly1d(coefficients)
#
# File <__array_function__ internals>:180, in polyfit(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\numpy\lib\polynomial.py:642, in polyfit(x, y, deg, rcond, full, w, cov)
#     640     raise TypeError("expected 1D or 2D array for y")
#     641 if x.shape[0] != y.shape[0]:
# --> 642     raise TypeError("expected x and y to have same length")
#     644 # set rcond
#     645 if rcond is None:
#
# TypeError: expected x and y to have same length

# %%
import numpy as np
import matplotlib.pyplot as plt

# Example data
x = np.array([1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021])
y = np.array(b1)

# Choose the degree of the polynomial
degree = 2

# Perform polynomial regression
coefficients = np.polyfit(x, y, degree)

# Form the polynomial equation
equation = np.poly1d(coefficients)
print("Polynomial Equation:", equation)

# Generate 30 new points for prediction
x_pred = np.array([2022,2023,2024,2025,2026,2027,2028,2029,2030,2031,2100])

# Make predictions using the polynomial equation
y_pred = equation(x_pred)

# Plot the original data points
plt.scatter(x, y, label='Original Data')

# Plot the fitted curve
plt.plot(x_pred, y_pred, label='Fitted Curve', color='red')

# Customize the plot
plt.title('Polynomial Regression')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 12
#       9 degree = 2
#      11 # Perform polynomial regression
# ---> 12 coefficients = np.polyfit(x, y, degree)
#      14 # Form the polynomial equation
#      15 equation = np.poly1d(coefficients)
#
# File <__array_function__ internals>:180, in polyfit(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\numpy\lib\polynomial.py:642, in polyfit(x, y, deg, rcond, full, w, cov)
#     640     raise TypeError("expected 1D or 2D array for y")
#     641 if x.shape[0] != y.shape[0]:
# --> 642     raise TypeError("expected x and y to have same length")
#     644 # set rcond
#     645 if rcond is None:
#
# TypeError: expected x and y to have same length

# %%
# Form the polynomial equation
equation = np.poly1d(coefficients)
print("Polynomial Equation:", equation)

# Generate 30 new points for prediction
x_pred = np.linspace(1, 10, 30)

# Make predictions using the polynomial equation
y_pred = equation(x_pred)

# Store predicted points in an array
predicted_points = np.column_stack(( y_pred))
print("Predicted Points:")
print(predicted_points)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Form the polynomial equation
# ----> 2 equation = np.poly1d(coefficients)
#       3 print("Polynomial Equation:", equation)
#       5 # Generate 30 new points for prediction
#
# NameError: name 'coefficients' is not defined

# %%
import numpy as np
from scipy.optimize import minimize

# Define the objective function
def objective_function(params, *args):
    a, b, c, d = params
    x, y = args
    predicted_x = np.zeros_like(x)

    for t in range(1, len(x)):
        predicted_x[t] = x[t-1] * (1 - d) + c * np.exp(a * np.exp(b * y[t]))

    return np.sum((x[1:] - predicted_x[1:]) ** 2)

# Initial guess for parameters
initial_params = [0,0,0,0]  # Provide initial values

# Additional arguments for the objective function
args = (a1, b1)

# Minimize the objective function
result = minimize(objective_function, initial_params, args=args)

# Extract the optimized parameters
optimized_params = result.x

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize

# Define the objective function
def objective_function(params, *args):
    a, b, c, d = params
    x, y = args
    predicted_x = np.zeros_like(x)

    for t in range(1, len(x)):
        predicted_x[t] = x[t-1] * (1 - d) + c * np.exp(a * np.exp(b * y[t]))

    return np.sum((x[1:] - predicted_x[1:]) ** 2)

# Your actual data
# Replace these with your own data
your_x_sequence = np.array(a1)  # Your x sequence
your_y_sequence = np.array(b1)  # Your y sequence

 # Your y sequence

# Initial guess for parameters
initial_params = [0,0,0,0]  # Provide initial values

# Additional arguments for the objective function
args = (your_x_sequence, your_y_sequence)

# Minimize the objective function
result = minimize(objective_function, initial_params, args=args)

# Extract the optimized parameters
optimized_params = result.x

# Generate predicted values using the optimized parameters
predicted_x = np.zeros_like(your_y_sequence)
for t in range(1, len(your_x_sequence)):
    predicted_x[t] = your_x_sequence[t-1] * (1 - optimized_params[3]) + optimized_params[2] * np.exp(optimized_params[0] * np.exp(optimized_params[1] * your_y_sequence[t]))

# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(your_x_sequence, label='Observed', marker='o')
plt.plot(predicted_x, label='Predicted', marker='x')
plt.xlabel('Time')
plt.ylabel('x(t)')
plt.legend()
plt.title('Fit of the Model to Observed Data')
plt.show()

# %%
print(optimized_params)
# Out:
# [ 1.11871134e+01 -1.43744760e-05  5.16472620e-05  1.07341249e-02]

# %%
# Extend the plot for the next 30 points
num_future_points = 15
extended_y_sequence = np.arange(len(your_x_sequence), len(your_x_sequence) + num_future_points)

for t in range(len(your_x_sequence), len(your_x_sequence) + num_future_points):
    predicted_x[t] = predicted_x[t-1] * (1 - optimized_params[3]) + optimized_params[2] * np.exp(optimized_params[0] * np.exp(optimized_params[1] * your_y_sequence[t]))

# Plot the extended results
plt.figure(figsize=(10, 6))
plt.plot(your_x_sequence, label='Observed', marker='o')
plt.plot(extended_y_sequence, predicted_x[len(your_x_sequence):], label='Predicted (Extended)', marker='x')
plt.xlabel('Time')
plt.ylabel('x(t)')
plt.legend()
plt.title('Extended Fit of the Model to Observed Data')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[68], line 11
#       9 plt.figure(figsize=(10, 6))
#      10 plt.plot(your_x_sequence, label='Observed', marker='o')
# ---> 11 plt.plot(extended_y_sequence, predicted_x[len(your_x_sequence):], label='Predicted (Extended)', marker='x')
#      12 plt.xlabel('Time')
#      13 plt.ylabel('x(t)')
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:2785, in plot(scalex, scaley, data, *args, **kwargs)
#    2783 @_copy_docstring_and_deprecators(Axes.plot)
#    2784 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2785     return gca().plot(
#    2786         *args, scalex=scalex, scaley=scaley,
#    2787         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
# ...

# %%
 x= predicted_x[33] * (1 - optimized_params[3]) + optimized_params[2] * np.exp(optimized_params[0] * np.exp(optimized_params[1] * your_y_sequence[34]))

# %%
print(predicted_x_prev)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 print(predicted_x_prev)
#
# NameError: name 'predicted_x_prev' is not defined

# %%
print(predicted_x)
# Out:
# [  0.          36.32146101  40.19421501  43.62751945  46.59053973
#   48.24382464  49.5932315   51.5591522   54.02806604  56.89929259
#   60.11128033  59.35054034  60.53001854  61.44415631  62.49266052
#   70.47176952  78.43764452  80.89550334  79.41960234  83.49704436
#   87.38291212  90.85581099  89.28988101  93.22405072  97.30008956
#  101.43387071 103.50708646 106.58067256 109.29935463 113.15394752
#  115.33161237 117.91619779 111.63352572 110.29067468 111.18537265
#  111.95585008 112.6010263  113.12119648 113.51727751 113.79034297
#  113.92450305 113.8936084  113.76859178 113.57453481 113.29190753
#  112.88807757 112.30953755 111.7775626  111.28245036   0.        ]

# %%
print(x)
# Out:
# 111.18537265047964

# %%
plt.figure(figsize=(10, 6))
plt.plot(your_x_sequence, label='Observed', marker='o')
plt.plot(predicted_x, label='Predicted', marker='x')
plt.xlabel('Time')
plt.ylabel('x(t)')
plt.legend()
plt.title('Fit of the Model to Observed Data')
plt.show()

# %%
print(4.43349931 +4.58593504+
+ 4.74097204+ 4.89856011+ 5.05864133 +5.22115006+ 5.38601314 +5.5531501)
# Out:
# 39.877921130000004

# %%
new_population = [37.221,38.077,38.939,39.807,40.682,41.564,42.452,43.345]
new_cars = predicted_x[41:49]

# %%
print(new_cars)
# Out:
# [113.8936084  113.76859178 113.57453481 113.29190753 112.88807757
#  112.30953755 111.7775626  111.28245036]

# %%
cars=0
for i in range(0,8):
    cars=cars+ (new_population[i]*new_cars[i]/1000)
    
print(cars)
# Out:
# 36.332755729829614

# %%
arr=[[[5273371.0, 2508334.0, 445153.5, 482942.5, 518638.5, 558083.5, 601231.5, 646265.5, 698406.5, 748719.0, 799986.0, 854691.5, 914813.5, 981375.5, 1050364.0, 1117880.5, 1190100.5, 1263436.0, 1338611.5, 1419997.0, 1509938.5, 1606653.5, 1701954.0, 1788411.0, 1884045.0, 1999240.5, 2105213.0, 2214233.0, 2321781.0, 2429467.0, 2553057.5, 2686906.0, 2817419.5, 2937744.0, 3060391.5, 3198127.0, 3340370.5, 3472873.5, 3605319.0, 3756739.5, 3897557.0, 4016628.0, 4163310.5, 4311315.5, 4455387.5, 4598620.0, 4735585.0, 4871170.0, 5010906.5, 5154599.0, 5289586.0, 5413556.0, 5540435.5, 5675963.0, 5804866.5, 5916819.0, 6011993.0, 6126556.0, 6235461.0, 6333590.5, 6435825.5, 6528021.0, 6617525.5, 6673369.5, 6735297.0, 6813566.0, 6864016.5, 6918388.5, 6968494.0, 6999475.0, 7021325.0, 7041588.0, 7057354.5, 7053789.5, 7035642.5, 7024568.0, 7021371.0, 7011653.5, 6973853.0, 6915168.5, 6873860.5, 6816521.5, 6762391.0, 6698083.0, 6613270.5, 6535921.5, 6440103.5, 6350760.0, 6247812.0, 6130949.0, 6017846.5, 5905606.5, 5788019.0, 5667407.0, 5538181.5, 5415902.0, 5293507.5, 5146905.5, 5013218.0, 4