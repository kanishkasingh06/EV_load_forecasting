# %%
def calculate_population_distribution(total_population, avg_income, median_income, subdivision_data):
    # Define the income proportions
    income_proportions = {
        'Low-Income': 0.304,
        'Lower-Middle-Income': 0.225,
        'Upper-Middle-Income': 0.207,
        'High-Income': 0.141
    }

    result = {}

    # Iterate over each subdivision
    for subdivision in subdivision_data:
        sub_population = subdivision['Population']
        sub_avg_income = subdivision['Per capita income']
        sub_median_income = subdivision['median income']

        # Initialize data structure for subdivision
        result[subdivision['subdivision_name']] = {}

        # Calculate population distribution in each income category
        for category, proportion in income_proportions.items():
            # Adjust th4e proportion based on the subdivision's average and median income
            adjusted_proportion = proportion  * (sub_median_income / median_income)
            # Multiply the adjusted proportion by the subdivision's population
            result[subdivision['subdivision_name']][category] = int(adjusted_proportion * sub_population)

    return result

# %%
def calculate_population_distribution_(total_population, avg_income, median_income, subdivision_data):
    # Define the income proportions
    income_proportions = {
        'Low-Income': 0.304,
        'Lower-Middle-Income': 0.225,
        'Upper-Middle-Income': 0.207,
        'High-Income': 0.141
    }

    result = []

    # Iterate over each subdivision
    for subdivision in subdivision_data:
        sub_population = subdivision['Population']
        sub_avg_income = subdivision['Per capita income']
        sub_median_income = subdivision['median income']

        # Initialize data structure for subdivision
        subdivision_result = [subdivision['subdivision_name']]

        # Calculate population distribution in each income category
        for category, proportion in income_proportions.items():
            # Adjust the proportion based on the subdivision's average and median income
            adjusted_proportion = proportion *(sub_median_income / median_income)
            # Multiply the adjusted proportion by the subdivision's population
            
            subdivision_result.append(int(adjusted_proportion * sub_population))

        result.append(subdivision_result)

    return result

# %%
ans=[0]*len(result)
for i in range(len(result)):
    ans[i]=result[i][1:]
print(ans)
# Out:
# [[778551, 576230, 530131, 361104], [879617, 651032, 598950, 407980], [472050, 349379, 321429, 218944], [341242, 252564, 232359, 158273], [681054, 504069, 463744, 315883], [871343, 644908, 593316, 404142], [487100, 360518, 331676, 225924], [1165860, 862889, 793858, 540744], [1490901, 1103463, 1015186, 691503], [401551, 297200, 273424, 186245], [582135, 430856, 396388, 270003], [353010, 261274, 240372, 163732], [165508, 122498, 112698, 76765], [240251, 177817, 163592, 111432], [176848, 130890, 120419, 82024], [192201, 142254, 130873, 89145], [368149, 272479, 250681, 170753], [338732, 250706, 230650, 157109], [433675, 320976, 295298, 201145], [540554, 400081, 368074, 250717], [692540, 512571, 471565, 321211], [888461, 657578, 604972, 412082], [438815, 324781, 298798, 203529], [810737, 600052, 552048, 376033], [472235, 349516, 321554, 219030], [1093591, 809401, 744649, 507225], [398350, 294832, 271245, 184761], [514645, 380905, 350432, 238700], [702301, 519795, 478211, 325738], [266974, 
# ...

# %%
subdivision_data_additional = [
    {'subdivision_name': 'Civil Lines', 'Population': 266385, 'Per capita income': 85000, 'median income': 75000},
    {'subdivision_name': 'Gandhi Nagar', 'Population': 325650, 'Per capita income': 90000, 'median income': 84000},
    {'subdivision_name': 'Chanakyapuri', 'Population': 103675, 'Per capita income': 125000, 'median income': 115000},
    {'subdivision_name': 'Alipur', 'Population': 132567, 'Per capita income': 80000, 'median income': 66000},
    {'subdivision_name': 'Karawal Nagar', 'Population': 225789, 'Per capita income': 75000, 'median income': 60000},
    {'subdivision_name': 'Kanjhawala', 'Population': 153891, 'Per capita income': 90000, 'median income': 54000},
    {'subdivision_name': 'Seemapuri', 'Population': 225789, 'Per capita income': 75000, 'median income': 48000},
    {'subdivision_name': 'Hauz Khas', 'Population': 123567, 'Per capita income': 120000, 'median income': 105000},
    {'subdivision_name': 'Defence Colony', 'Population': 112356, 'Per capita income': 85000, 'median income': 80000},
    {'subdivision_name': 'Dwarka', 'Population': 266385, 'Per capita income': 85000, 'median income': 81000},
    {'subdivision_name': 'Patel Nagar', 'Population': 325650, 'Per capita income': 90000, 'median income': 78000},
    {'subdivision_name': 'Karol Bagh', 'Population': 295841, 'Per capita income': 110000, 'median income': 90000},
    {'subdivision_name': 'Mayur Vihar', 'Population': 385374, 'Per capita income': 125000, 'median income': 78000},
    {'subdivision_name': 'Delhi Cantonment', 'Population': 110464, 'Per capita income': 160000, 'median income': 105000},
    {'subdivision_name': 'Model Town', 'Population': 274734, 'Per capita income': 130000, 'median income': 96000},
    {'subdivision_name': 'Seelampur', 'Population': 554760, 'Per capita income': 75000, 'median income': 48000},
    {'subdivision_name': 'Rohini', 'Population': 811389, 'Per capita income': 95000, 'median income': 60000},
    {'subdivision_name': 'Shahdara', 'Population': 389970, 'Per capita income': 80000, 'median income': 54000},
    {'subdivision_name': 'Mehrauli', 'Population': 197414, 'Per capita income': 110000, 'median income': 100000},
    {'subdivision_name': 'Kalkaji', 'Population': 179679, 'Per capita income': 145000, 'median income': 114000},
    {'subdivision_name': 'Kapashera', 'Population': 167269, 'Per capita income': 90000, 'median income': 75000},
    {'subdivision_name': 'Punjabi Bagh', 'Population': 256374, 'Per capita income': 155000, 'median income': 99000},
    {'subdivision_name': 'Kotwali', 'Population': 234567, 'Per capita income': 135000, 'median income': 60000},
    {'subdivision_name': 'Preet Vihar', 'Population': 345678, 'Per capita income': 140000, 'median income': 84000},
    {'subdivision_name': 'Vasant Vihar', 'Population': 156789, 'Per capita income': 175000, 'median income': 120000},
    {'subdivision_name': 'Narela', 'Population': 765432, 'Per capita income': 90000, 'median income': 54000},
    {'subdivision_name': 'Yamuna Vihar', 'Population': 432109, 'Per capita income': 70000, 'median income': 66000},
    {'subdivision_name': 'Saraswati Vihar', 'Population': 210987, 'Per capita income': 95000, 'median income': 72000},
    {'subdivision_name': 'Vivek Vihar', 'Population': 321098, 'Per capita income': 115000, 'median income': 78000},
    {'subdivision_name': 'Saket', 'Population': 165432, 'Per capita income': 165000, 'median income': 135000},
    {'subdivision_name': 'Sarita Vihar', 'Population': 254321, 'Per capita income': 95000, 'median income': 90000},
    {'subdivision_name': 'Najafgarh', 'Population': 876543, 'Per capita income': 80000, 'median income': 70000},
    {'subdivision_name': 'Rajouri Garden', 'Population': 345678, 'Per capita income': 190000, 'median income': 96000},
    # Add more subdivisions as needed
]
for i in range(len(subdivision_data_additional)):
    subdivision_data_additional[i]['no_of_cars']= subdivision_data_additional[i]['Population']*114.98/1000

# %%
arr=[]
for i in range(33):
    arr.append(subdivision_data_additional[i]['median income'])
print(arr)
# Out:
# [75000, 84000, 115000, 66000, 60000, 54000, 48000, 105000, 150000, 76000, 78000, 90000, 78000, 105000, 96000, 48000, 60000, 54000, 100000, 114000, 75000, 99000, 60000, 84000, 120000, 54000, 66000, 72000, 78000, 135000, 85000, 70000, 96000]

# %%
print(subdivision_data_additional)
# Out:
# [{'subdivision_name': 'Civil Lines', 'Population': 266385, 'Per capita income': 85000, 'median income': 75000, 'no_of_cars': 30628.9473}, {'subdivision_name': 'Gandhi Nagar', 'Population': 325650, 'Per capita income': 90000, 'median income': 84000, 'no_of_cars': 37443.237}, {'subdivision_name': 'Chanakyapuri', 'Population': 103675, 'Per capita income': 125000, 'median income': 115000, 'no_of_cars': 11920.5515}, {'subdivision_name': 'Alipur', 'Population': 132567, 'Per capita income': 80000, 'median income': 66000, 'no_of_cars': 15242.55366}, {'subdivision_name': 'Karawal Nagar', 'Population': 225789, 'Per capita income': 75000, 'median income': 60000, 'no_of_cars': 25961.219220000003}, {'subdivision_name': 'Kanjhawala', 'Population': 153891, 'Per capita income': 90000, 'median income': 54000, 'no_of_cars': 17694.387179999998}, {'subdivision_name': 'Seemapuri', 'Population': 225789, 'Per capita income': 75000, 'median income': 48000, 'no_of_cars': 25961.219220000003}, {'subdivision_na
# ...

# %%
p=0
for i in range(len(subdivision_data_additional)):
    p=p+subdivision_data_additional[i]['Population']
print(p)
# Out:
# 9993606

# %%
pop=43345000
cars=114.98*pop/1000
print(cars)
# Out:
# 4983808.1

# %%
for i in range(len(subdivision_data_additional)):
    subdivision_data_additional[i]['ratio']=subdivision_data_additional[i]['Population']/9993606

    subdivision_data_additional[i]['cars']=subdivision_data_additional[i]['ratio']*4983808.1

# %%
print(subdivision_data_additional)
# Out:
# [{'subdivision_name': 'Civil Lines', 'Population': 266385, 'Per capita income': 85000, 'median income': 75000, 'no_of_cars': 30628.9473, 'ratio': 0.02665554355454878, 'cars': 132846.11387706298}, {'subdivision_name': 'Gandhi Nagar', 'Population': 325650, 'Per capita income': 90000, 'median income': 84000, 'no_of_cars': 37443.237, 'ratio': 0.03258583538314398, 'cars': 162401.55032777958}, {'subdivision_name': 'Chanakyapuri', 'Population': 103675, 'Per capita income': 125000, 'median income': 115000, 'no_of_cars': 11920.5515, 'ratio': 0.010374133220781368, 'cars': 51702.689176209264}, {'subdivision_name': 'Alipur', 'Population': 132567, 'Per capita income': 80000, 'median income': 66000, 'no_of_cars': 15242.55366, 'ratio': 0.013265181757215564, 'cars': 66111.12028958315}, {'subdivision_name': 'Karawal Nagar', 'Population': 225789, 'Per capita income': 75000, 'median income': 60000, 'no_of_cars': 25961.219220000003, 'ratio': 0.02259334618555104, 'cars': 112600.90172565337}, {'subdivisio
# ...

# %%
arr=[]

for i in range(len(subdivision_data_additional)):
    arr.append([int(subdivision_data_additional[i]['cars']*0.304),int(subdivision_data_additional[i]['cars']*0.225),
               int(subdivision_data_additional[i]['cars']*0.207),int(subdivision_data_additional[i]['cars']*0.141)])
print(arr)
# Out:
# [[40385, 29890, 27499, 18731], [49370, 36540, 33617, 22898], [15717, 11633, 10702, 7290], [20097, 14875, 13685, 9321], [34230, 25335, 23308, 15876], [23330, 17267, 15886, 10821], [34230, 25335, 23308, 15876], [18733, 13865, 12755, 8688], [17033, 12607, 11598, 7900], [40385, 29890, 27499, 18731], [49370, 36540, 33617, 22898], [44850, 33195, 30539, 20802], [58424, 43241, 39782, 27098], [16746, 12394, 11403, 7767], [41650, 30827, 28361, 19318], [84104, 62248, 57268, 39008], [123010, 91043, 83760, 57054], [59121, 43757, 40256, 27421], [29928, 22151, 20379, 13881], [27240, 20161, 18548, 12634], [25358, 18768, 17267, 11761], [38867, 28767, 26465, 18027], [35561, 26320, 24214, 16493], [52406, 38787, 35684, 24306], [23769, 17592, 16185, 11024], [116043, 85887, 79016, 53822], [65509, 48485, 44606, 30384], [31986, 23674, 21780, 14835], [48679, 36029, 33147, 22578], [25080, 18562, 17077, 11632], [38556, 28536, 26253, 17883], [132888, 98354, 90486, 61635], [52406, 38787, 35684, 24306]]

# %%
arr1=[]

for i in range(len(subdivision_data_additional)):
    subdivision_data_additional[i]['Population']=int(subdivision_data_additional[i]['ratio']*43345000)
    arr1.append(int(subdivision_data_additional[i]['ratio']*43345000))
print(arr1)
# Out:
# [1155384, 1412433, 449666, 574979, 979308, 667467, 979308, 535943, 487318, 1155384, 1412433, 1283143, 1671472, 479112, 1191596, 2406145, 3519215, 1691406, 856238, 779316, 725491, 1111964, 1017381, 1499299, 680036, 3319887, 1874174, 915108, 1392689, 717523, 1103059, 3801806, 1499299]

# %%
print(sum(arr1))
# Out:
# 43344982

# %%
for i in range(33):
    print(subdivision_data_additional['subdivision_name'],subdivision_data_additional['Population'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 for i in range(33):
# ----> 2     print(subdivision_data_additional['subdivision_name'],subdivision_data_additional['Population'])
#
# TypeError: list indices must be integers or slices, not str

# %%
print(subdivision_data_additional)
# Out:
# [{'subdivision_name': 'Civil Lines', 'Population': 1155384, 'Per capita income': 85000, 'median income': 75000, 'no_of_cars': 30628.9473, 'ratio': 0.02665554355454878, 'cars': 132846.11387706298}, {'subdivision_name': 'Gandhi Nagar', 'Population': 1412433, 'Per capita income': 90000, 'median income': 84000, 'no_of_cars': 37443.237, 'ratio': 0.03258583538314398, 'cars': 162401.55032777958}, {'subdivision_name': 'Chanakyapuri', 'Population': 449666, 'Per capita income': 120000, 'median income': 120000, 'no_of_cars': 11920.5515, 'ratio': 0.010374133220781368, 
    # Define the income proportions
    income_proportions = {
        'Low-Income': 0.304,
        'Lower-Middle-Income': 0.225,
        'Upper-Middle-Income': 0.207,
        'High-Income': 0.141
    }

    result = []

    # Iterate over each subdivision
    for subdivision in subdivision_data:
        sub_population = subdivision['Population']
        sub_avg_income = subdivision['Per capita income']
        sub_median_income = subdivision['median income']

        # Initialize data structure for subdivision
        subdivision_result = [subdivision['subdivision_name']]
     
            # Multiply the adjusted proportion by the subdivision's population
        for category, proportion in income_proportions.items():
            # Adjust the proportion based on the subdivision's average and median income
        
        
            subdivision_result.append(int(proportion * sub_population))
      
        result.append(subdivision_result)

    return result

# %%
result1 = calculate_population_distribution_(43345000, 294321, 360000, subdivision_data_additional)

# Print the result as a list of lists
print(result1)
# Out:
# [['Civil Lines', 351236, 259961, 239164, 162909], ['Gandhi Nagar', 429379, 317797, 292373, 199153], ['Chanakyapuri', 136698, 101174, 93080, 63402], ['Alipur', 174793, 129370, 119020, 81072], ['Karawal Nagar', 297709, 220344, 202716, 138082], ['Kanjhawala', 202909, 150180, 138165, 94112], ['Seemapuri', 297709, 220344, 202716, 138082], ['Hauz Khas', 162926, 120587, 110940, 75567], ['Defence Colony', 148144, 109646, 100874, 68711], ['Dwarka', 351236, 259961, 239164, 162909], ['Patel Nagar', 429379, 317797, 292373, 199153], ['Karol Bagh', 390075, 288707, 265610, 180923], ['Mayur Vihar', 508127, 376081, 345994, 235677], ['Delhi Cantonment', 145650, 107800, 99176, 67554], ['Model Town', 362245, 268109, 246660, 168015], ['Seelampur', 731468, 541382, 498072, 339266], ['Rohini', 1069841, 791823, 728477, 496209], ['Shahdara', 514187, 380566, 350121, 238488], ['Mehrauli', 260296, 192653, 177241, 120729], ['Kalkaji', 236912, 175346, 161318, 109883], ['Kapashera', 220549, 163235, 150176, 102294],
# ...

# %%
ans=[0]*len(result1)
for i in range(len(result1)):
    ans[i]=result1[i][1:]
print(ans)
# Out:
# [[351236, 259961, 239164, 162909], [429379, 317797, 292373, 199153], [136698, 101174, 93080, 63402], [174793, 129370, 119020, 81072], [297709, 220344, 202716, 138082], [202909, 150180, 138165, 94112], [297709, 220344, 202716, 138082], [162926, 120587, 110940, 75567], [148144, 109646, 100874, 68711], [351236, 259961, 239164, 162909], [429379, 317797, 292373, 199153], [390075, 288707, 265610, 180923], [508127, 376081, 345994, 235677], [145650, 107800, 99176, 67554], [362245, 268109, 246660, 168015], [731468, 541382, 498072, 339266], [1069841, 791823, 728477, 496209], [514187, 380566, 350121, 238488], [260296, 192653, 177241, 120729], [236912, 175346, 161318, 109883], [220549, 163235, 150176, 102294], [338037, 250191, 230176, 156786], [309283, 228910, 210597, 143450], [455786, 337342, 310354, 211401], [206730, 153008, 140767, 95885], [1009245, 746974, 687216, 468104], [569748, 421689, 387954, 264258], [278192, 205899, 189427, 129030], [423377, 313355, 288286, 196369], [218126, 161442, 1
# ...

# %%
# Example 2D array
two_d_array =ans

# Flatten the 2D array
flattened_array = [int(element) for row in two_d_array for element in row]

# Calculate the sum of the flattened array
sum_of_array = sum(flattened_array)

# Print the result
print("Flattened array:", flattened_array)
print("Sum of the flattened array:", sum_of_array)
# Out:
# Flattened array: [351236, 259961, 239164, 162909, 429379, 317797, 292373, 199153, 136698, 101174, 93080, 63402, 174793, 129370, 119020, 81072, 297709, 220344, 202716, 138082, 202909, 150180, 138165, 94112, 297709, 220344, 202716, 138082, 162926, 120587, 110940, 75567, 148144, 109646, 100874, 68711, 351236, 259961, 239164, 162909, 429379, 317797, 292373, 199153, 390075, 288707, 265610, 180923, 508127, 376081, 345994, 235677, 145650, 107800, 99176, 67554, 362245, 268109, 246660, 168015, 731468, 541382, 498072, 339266, 1069841, 791823, 728477, 496209, 514187, 380566, 350121, 238488, 260296, 192653, 177241, 120729, 236912, 175346, 161318, 109883, 220549, 163235, 150176, 102294, 338037, 250191, 230176, 156786, 309283, 228910, 210597, 143450, 455786, 337342, 310354, 211401, 206730, 153008, 140767, 95885, 1009245, 746974, 687216, 468104, 569748, 421689, 387954, 264258, 278192, 205899, 189427, 129030, 423377, 313355, 288286, 196369, 218126, 161442, 148527, 101170, 335329, 248188, 228333, 155
# ...

# %%
import numpy as np
from scipy.stats import lognorm

# Given values
mean_X = 115500
median_X = 100323

# Calculate mu and sigma
mu = np.log(median_X)
sigma = np.sqrt(2 * np.log(mean_X / median_X))

# Define the ranges
ranges = [
    (None, 50000),
    (50000, 100000),
    (100000, 250000),
    (250000, None)
]

# Calculate the fraction for each range
fractions = []
for lower, upper in ranges:
    if lower is None:
        fraction = lognorm.cdf(upper, s=sigma, scale=np.exp(mu))
    elif upper is None:
        fraction = 1 - lognorm.cdf(lower, s=sigma, scale=np.exp(mu))
    else:
        fraction = lognorm.cdf(upper, s=sigma, scale=np.exp(mu)) - lognorm.cdf(lower, s=sigma, scale=np.exp(mu))
    fractions.append(fraction)

# Print the results
for i, (lower, upper) in enumerate(ranges):
    if lower is None:
        print(f"Fraction below {upper}: {fractions[i]:.4f}")
    elif upper is None:
        print(f"Fraction above {lower}: {fractions[i]:.4f}")
    else:
        print(f"Fraction between {lower} and {upper}: {fractions[i]:.4f}")
# Out:
# Fraction below 50000: 0.0948
# Fraction between 50000 and 100000: 0.4028
# Fraction between 100000 and 250000: 0.4597
# Fraction above 250000: 0.0427

# %%
f=[]
for i in range(33):
    mean_X= subdivision_data_additional[i]['Per capita income']
    median_X=subdivision_data_additional[i]['median income']
    import numpy as np
    from scipy.stats import lognorm
    
    
    # Calculate mu and sigma
    mu = np.log(median_X)
    sigma = np.sqrt(2 * np.log(mean_X / median_X))
    
    # Define the ranges
    ranges = [
        (None, 50000),
        (50000, 100000),
        (100000, 250000),
        (250000, None)
    ]
    
    # Calculate the fraction for each range
    fractions = []
    for lower, upper in ranges:
        if lower is None:
            fraction = lognorm.cdf(upper, s=sigma, scale=np.exp(mu))
        elif upper is None:
            fraction = 1 - lognorm.cdf(lower, s=sigma, scale=np.exp(mu))
        else:
            fraction = lognorm.cdf(upper, s=sigma, scale=np.exp(mu)) - lognorm.cdf(lower, s=sigma, scale=np.exp(mu))
        fractions.append(fraction)
    f.append(fractions)

# %%
print(f[0])
print(f[8])
print(f[10])
# Out:
# [0.2088547155393647, 0.508495931669662, 0.27459351180798874, 0.008055840982984619]
# [0.088543927419717, 0.6506404553415122, 0.2602821880419647, 0.0005334291968062121]
# [0.20292402889470063, 0.47590707704314994, 0.30643589760148626, 0.014732996460663172]

# %%
population = [
    1155384, 1412433, 449666, 574979, 979308, 667467, 979308, 535943, 487318, 
    1155384, 1412433, 1283143, 1671472, 479112, 1191596, 2406145, 3519215, 
    1691406, 856238, 779316, 725491, 1111964, 1017381, 1499299, 680036, 
    3319887, 1874174, 915108, 1392689, 717523, 1103059, 3801806, 1499299
]

# %%
import numpy as np
popy= []
for i in range(33):
    x=[]
    for j in range(4):
        x.append(int(population_d[i][j]/population[i]))
    popy.append(x)

# %%
print(popy)
# Out:
# [[241307, 587508, 317260, 9307], [114780, 846516, 448788, 2347], [9305, 155309, 272183, 12867], [188146, 242245, 135449, 9137], [384337, 377330, 201648, 15991], [313478, 173067, 137708, 43212], [506529, 258687, 174584, 39505], [40488, 207327, 263147, 24979], [43149, 317068, 126840, 259], [69463, 798608, 287148, 163], [286616, 672186, 432820, 20809], [226796, 499518, 488297, 68530], [540755, 463732, 474423, 192561], [100346, 129053, 167165, 82545], [239625, 381081, 440392, 130496], [1244536, 635592, 428951, 97065], [1494202, 979555, 805120, 240336], [787203, 492291, 340951, 70959], [48110, 380008, 412773, 15345], [91463, 239808, 347681, 100361], [182072, 313516, 213153, 16749], [261678, 299012, 368950, 182322], [450781, 216448, 216641, 133508], [455610, 396705, 436649, 210333], [106608, 176883, 261166, 135377], [1559196, 860815, 684944, 214931], [392016, 1270563, 211496, 96], [285665, 327878, 258293, 43270], [427415, 423540, 412057, 129675], [41945, 186120, 370803, 118652], [40737, 64
# ...

# %%
p_sum=0
for i in range(33):
    for j in range(4):
        p_sum=p_sum+popy[i][j]

# %%
print(p_sum)
# Out:
# 43344914

# %%
print(sum(population)*115/1000)
# Out:
# 4984672.93

# %%
print(f)
# Out:
# [[0.2088547155393647, 0.508495931669662, 0.27459351180798874, 0.008055840982984619], [0.0812642234393372, 0.5993323918291438, 0.3177413718411939, 0.001662012890325082], [0.02069450999844989, 0.3453882524752254, 0.6053021405941174, 0.028615096932207318], [0.3272234716650237, 0.4213115230226135, 0.23557292424264364, 0.015892081069719177], [0.3924584454669602, 0.38530303599305593, 0.2059090255330822, 0.016329493006901674], [0.46965338940648266, 0.2592904740594782, 0.20631560960737805, 0.0647405269266611], [0.5172324488813353, 0.26415366963412457, 0.17827332626185732, 0.04034055522268276], [0.07554534763724978, 0.38684573284757656, 0.4909998842546015, 0.04660903526057214], [0.088543927419717, 0.6506404553415122, 0.2602821880419647, 0.0005334291968062121], [0.06012129958221605, 0.6912058277775525, 0.24853104193380782, 0.00014183070642370676], [0.20292402889470063, 0.47590707704314994, 0.30643589760148626, 0.014732996460663172], [0.17675101509207358, 0.3892928704674752, 0.38054807910141897
 640], [13567, 29441, 22676, 476], [16289, 45374, 42563, 1180], [8582, 22803, 18024, 348], [524, 17602, 21821, 75], [997, 11108, 18380, 492], [1984, 14522, 11268, 82], [2852, 13850, 19504, 895], [4914, 10026, 11452, 655], [4967, 18376, 23083, 1032], [1162, 8193, 13806, 664], [16998, 39874, 36209, 1055], [4273, 58855, 11180, 0], [3114, 15187, 13654, 212], [4659, 19619, 21783, 636], [457, 8621, 19602, 582], [444, 30082, 21773, 5], [10672, 87607, 47865, 128], [4712, 15668, 22169, 1519]]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate a random 2D array for demonstration
data =popy 
plt.figure(figsize=(4, 7))  # Adjust the width (12) and height (6) as needed

# Create a heatmap
plt.imshow(data, cmap='viridis', interpolation='nearest' , aspect='auto')
plt.xticks(np.arange(4), ['type D', 'type C', 'type B', 'type A'])  # Assuming you want labels from 1 to 33 on the x-axis
plt.yticks(np.arange(33), ['Civil Lines', 'Karol Bagh', 'Kotwali', 'Gandhi Nagar', 'Mayur Vihar', 'Preet Vihar', 'Chanakyapuri', 'Delhi Cantonment', 'Vasant Vihar', 'Alipur', 'Model Town', 'Narela', 'Karawal Nagar', 'Seelampur', 'Yamuna Vihar', 'Kanjhawala', 'Rohini', 'Saraswati Vihar', 'Seemapuri', 'Shahdara', 'Vivek Vihar', 'Hauz Khas', 'Mehrauli', 'Saket', 'Defence Colony', 'Kalkaji', 'Sarita Vihar', 'Dwarka', 'Kapashera', 'Najafgarh', 'Patel Nagar', 'Punjabi Bagh', 'Rajouri Garden'])
plt.colorbar()  # add colorbar on the right side of the plot

# %%
print(popy)
# Out:
# [[240, 584, 315, 9], [93, 689, 365, 1], [23, 397, 696, 32], [376, 484, 270, 18], [451, 443, 236, 18], [540, 298, 237, 74], [594, 303, 205, 46], [86, 444, 564, 53], [101, 748, 299, 0], [69, 794, 285, 0], [233, 547, 352, 16], [203, 447, 437, 61], [372, 319, 326, 132], [240, 309, 401, 198], [231, 367, 425, 125], [594, 303, 205, 46], [488, 320, 263, 78], [535, 334, 231, 48], [64, 510, 554, 20], [134, 353, 513, 148], [288, 496, 337, 26], [270, 309, 381, 188], [509, 244, 244, 150], [349, 304, 334, 161], [180, 299, 441, 228], [540, 298, 237, 74], [240, 779, 129, 0], [358, 412, 324, 54], [352, 349, 340, 107], [67, 298, 594, 190], [42, 677, 429, 1], [296, 572, 273, 7], [331, 259, 321, 237]]

# %%
for i in range(33):
    for j in range(4):
        popy[i][j]=popy[i][j]/115

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate a random 2D array for demonstration
data =popy 
plt.figure(figsize=(4, 7))  # Adjust the width (12) and height (6) as needed

# Create a heatmap
plt.imshow(data, cmap='viridis', interpolation='nearest' , aspect='auto')
plt.xticks(np.arange(4), ['type D', 'type C', 'type B', 'type A'])  # Assuming you want labels from 1 to 33 on the x-axis
plt.yticks(np.arange(33), ['Civil Lines', 'Karol Bagh', 'Kotwali', 'Gandhi Nagar', 'Mayur Vihar', 'Preet Vihar', 'Chanakyapuri', 'Delhi Cantonment', 'Vasant Vihar', 'Alipur', 'Model Town', 'Narela', 'Karawal Nagar', 'Seelampur', 'Yamuna Vihar', 'Kanjhawala', 'Rohini', 'Saraswati Vihar', 'Seemapuri', 'Shahdara', 'Vivek Vihar', 'Hauz Khas', 'Mehrauli', 'Saket', 'Defence Colony', 'Kalkaji', 'Sarita Vihar', 'Dwarka', 'Kapashera', 'Najafgarh', 'Patel Nagar', 'Punjabi Bagh', 'Rajouri Garden'])
plt.colorbar()  # add colorbar on the right side of the plot

# %%
loaded_data = np.loadtxt('output.txt', delimiter=' ').reshape(1000, 33, 4)

# %%
import numpy as np
final_arr=[]
for i in range(1000):
# The original array
    original_array = np.array(loaded_data[i])

    # Convert the array to integers
    integer_array = original_array.astype(int)
    final_arr.append(integer_array)
# Print the resulting integer array
print(integer_array)
# Out:
# [[  1071  33169  70459   1278]
#  [   500   1416  92176  19802]
#  [  1399  25870  23239   1570]
#  [  1050  15330  17470   9699]
#  [   635  10732  13466  15122]
#  [   937  18392  21380   1604]
#  [   916  20332  29879   4196]
#  [  1199  30618  21651   4922]
#  [   500  14212  18469  22905]
#  [   500   8459  25904  38418]
#  [   874  40942  80526  10634]
#  [  1159  17064  47480   1797]
#  [  3917  31603  34416  37671]
#  [   570  24043   7041   9136]
#  [  1446  18155  74896   7456]
#  [  1821   2907  83839  27088]
#  [  2801  25939  51947   4389]
#  [   558   2491  73020   8075]
#  [  1065  48144  24042  20461]
#  [  2940   3041  45768  12925]
#  [   722   3357  27905  32605]
#  [   558  39218  21474   7285]
#  [  2689  26529  11510  15787]
#  [   504   8742  72612  17209]
#  [  3024  24877  30221   3563]
#  [   583   2867  60428  37848]
#  [   500  23958  28768  46505]
#  [  2291  13543  53976   7985]
#  [   627  36366  68318   4469]
#  [  2283  43692   6101  20472]
# ...

# %%
average_array = np.mean(final_arr, axis=0)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate a random 2D array for demonstration
data =average_array
plt.figure(figsize=(4, 7))  # Adjust the width (12) and height (6) as needed

# Create a heatmap
plt.imshow(data, cmap='viridis', interpolation='nearest' , aspect='auto')
plt.xticks(np.arange(4), ['type A', 'type B', 'type C', 'type D'])  # Assuming you want labels from 1 to 33 on the x-axis
plt.yticks(np.arange(33), ['Civil Lines', 'Karol Bagh', 'Kotwali', 'Gandhi Nagar', 'Mayur Vihar', 'Preet Vihar', 'Chanakyapuri', 'Delhi Cantonment', 'Vasant Vihar', 'Alipur', 'Model Town', 'Narela', 'Karawal Nagar', 'Seelampur', 'Yamuna Vihar', 'Kanjhawala', 'Rohini', 'Saraswati Vihar', 'Seemapuri', 'Shahdara', 'Vivek Vihar', 'Hauz Khas', 'Mehrauli', 'Saket', 'Defence Colony', 'Kalkaji', 'Sarita Vihar', 'Dwarka', 'Kapashera', 'Najafgarh', 'Patel Nagar', 'Punjabi Bagh', 'Rajouri Garden'])
plt.colorbar()  # add colorbar on the right side of the plot
